# %% [markdown]
# #German Energy Market Analysis
# ## Data Understanding
#
# **Auther:** Rajbali Kumar
#
# **Date:** 16-01-2026
#
# **Objective:** To understand the structure, quality, and characteristics of the German energy dataset before cleaning or analysis.

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.max_row", 100)

# %%
df = pd.read_csv("../data/raw/energy_data_raw.csv")

print("Shape:", df.shape)
print("Memory usage(MB):", round(df.memory_usage(deep=True).sum() / 1024**2, 2))
# Out:
# Shape: (50401, 300)
# Memory usage(MB): 121.42

# %%
df.head()
# Out:
#           utc_timestamp        cet_cest_timestamp  \
# 0  2014-12-31T23:00:00Z  2015-01-01T00:00:00+0100
# 1  2015-01-01T00:00:00Z  2015-01-01T01:00:00+0100
# 2  2015-01-01T01:00:00Z  2015-01-01T02:00:00+0100
# 3  2015-01-01T02:00:00Z  2015-01-01T03:00:00+0100
# 4  2015-01-01T03:00:00Z  2015-01-01T04:00:00+0100
#
#    AT_load_actual_entsoe_transparency  AT_load_forecast_entsoe_transparency  \
# 0                                 NaN                                   NaN
# 1                              5946.0                                6701.0
# 2                              5726.0                                6593.0
# 3                              5347.0                                6482.0
# 4                              5249.0                                6454.0
#
#    AT_price_day_ahead  AT_solar_generation_actual  \
# 0                 NaN                         NaN
# 1                35.0                         NaN
# ...

# %%
df.tail()
# Out:
#               utc_timestamp        cet_cest_timestamp  \
# 50396  2020-09-30T19:00:00Z  2020-09-30T21:00:00+0200
# 50397  2020-09-30T20:00:00Z  2020-09-30T22:00:00+0200
# 50398  2020-09-30T21:00:00Z  2020-09-30T23:00:00+0200
# 50399  2020-09-30T22:00:00Z  2020-10-01T00:00:00+0200
# 50400  2020-09-30T23:00:00Z  2020-10-01T01:00:00+0200
#
#        AT_load_actual_entsoe_transparency  \
# 50396                              6661.0
# 50397                              6336.0
# 50398                              5932.0
# 50399                              5628.0
# 50400                              5395.0
#
#        AT_load_forecast_entsoe_transparency  AT_price_day_ahead  \
# 50396                                6656.0                 NaN
# 50397                                6310.0                 NaN
# 50398                                5813.0                 NaN
# 50399                                5424.0                 NaN
# ...

# %%
df.columns.tolist()
# Out:
# ['utc_timestamp',
#  'cet_cest_timestamp',
#  'AT_load_actual_entsoe_transparency',
#  'AT_load_forecast_entsoe_transparency',
#  'AT_price_day_ahead',
#  'AT_solar_generation_actual',
#  'AT_wind_onshore_generation_actual',
#  'BE_load_actual_entsoe_transparency',
#  'BE_load_forecast_entsoe_transparency',
#  'BE_solar_generation_actual',
#  'BE_wind_generation_actual',
#  'BE_wind_offshore_generation_actual',
#  'BE_wind_onshore_generation_actual',
#  'BG_load_actual_entsoe_transparency',
#  'BG_load_forecast_entsoe_transparency',
#  'BG_solar_generation_actual',
#  'BG_wind_onshore_generation_actual',
#  'CH_load_actual_entsoe_transparency',
#  'CH_load_forecast_entsoe_transparency',
#  'CH_solar_capacity',
#  'CH_solar_generation_actual',
#  'CH_wind_onshore_capacity',
#  'CH_wind_onshore_generation_actual',
#  'CY_load_actual_entsoe_transparency',
#  'CY_load_forecast_entsoe_transparency',
#  'CY_wind_onshore_generation_actual',
#  'CZ_load_actual_entsoe_transparency',
# ...

# %%
df.dtypes
# Out:
# utc_timestamp                            object
# cet_cest_timestamp                       object
# AT_load_actual_entsoe_transparency      float64
# AT_load_forecast_entsoe_transparency    float64
# AT_price_day_ahead                      float64
#                                          ...
# SK_load_forecast_entsoe_transparency    float64
# SK_solar_generation_actual              float64
# SK_wind_onshore_generation_actual       float64
# UA_load_actual_entsoe_transparency      float64
# UA_load_forecast_entsoe_transparency    float64
# Length: 300, dtype: object

# %%
df.iloc[:, 0].head()
# Out:
# 0    2014-12-31T23:00:00Z
# 1    2015-01-01T00:00:00Z
# 2    2015-01-01T01:00:00Z
# 3    2015-01-01T02:00:00Z
# 4    2015-01-01T03:00:00Z
# Name: utc_timestamp, dtype: object

# %%
df.iloc[:, 0].nunique()
# Out:
# 50401

# %%
missing = df.isnull().sum()
missing_percent = (missing / len(df)) * 100

missing_df = pd.DataFrame({
    "missing_count": missing,
    "missing_percent": missing_percent
})

missing_df[missing_df["missing_count"] > 0]
# Out:
#                                       missing_count  missing_percent
# AT_load_actual_entsoe_transparency                1         0.001984
# AT_load_forecast_entsoe_transparency              1         0.001984
# AT_price_day_ahead                            17556        34.832642
# AT_solar_generation_actual                       62         0.123013
# AT_wind_onshore_generation_actual                49         0.097220
# ...                                             ...              ...
# SK_load_forecast_entsoe_transparency              3         0.005952
# SK_solar_generation_actual                      391         0.775778
# SK_wind_onshore_generation_actual             40722        80.796016
# UA_load_actual_entsoe_transparency            24766        49.137914
# UA_load_forecast_entsoe_transparency          24988        49.578381
#
# [298 rows x 2 columns]

# %%
df.describe()
# Out:
#        AT_load_actual_entsoe_transparency  \
# count                        50400.000000
# mean                          7070.148631
# std                           1400.263167
# min                            664.000000
# 25%                           5941.000000
# 50%                           7032.000000
# 75%                           8079.000000
# max                          10803.000000
#
#        AT_load_forecast_entsoe_transparency  AT_price_day_ahead  \
# count                          50400.000000        32845.000000
# mean                            7039.848552           33.934663
# std                             1355.382837           14.944863
# min                             3739.000000          -76.000000
# 25%                             5941.000000           25.000000
# 50%                             7018.000000           33.000000
# 75%                             7986.000000           42.000000
# max                            11608.000000          187.000000
#
# ...
